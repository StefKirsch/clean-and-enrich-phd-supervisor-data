# %%
import requests

url = "https://api.elsevier.com/content/search/sciencedirect"
headers = {
    "Accept": "application/json",
    "X-ELS-APIKey": "353c54f205d5d9a3843469a0fbf4a11a"
}

params = {
    "query": "heart+attack", # random query  
    "view": "STANDARD",        
}

# GET request
response = requests.get(url, headers=headers,params=params)

print(response.json())
# Out:
# {'search-results': {'opensearch:totalResults': '52', 'opensearch:startIndex': '0', 'opensearch:itemsPerPage': '25', 'opensearch:Query': {'@role': 'request', '@searchTerms': 'heart+attack', '@startPage': '0'}, 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/search/sciencedirect?start=0&count=25&query=heart%2Battack&view=STANDARD', '@type': 'application/json'}, {'@_fa': 'true', '@ref': 'first', '@href': 'https://api.elsevier.com/content/search/sciencedirect?start=0&count=25&query=heart%2Battack&view=STANDARD', '@type': 'application/json'}, {'@_fa': 'true', '@ref': 'next', '@href': 'https://api.elsevier.com/content/search/sciencedirect?start=25&count=25&query=heart%2Battack&view=STANDARD', '@type': 'application/json'}, {'@_fa': 'true', '@ref': 'last', '@href': 'https://api.elsevier.com/content/search/sciencedirect?start=27&count=25&query=heart%2Battack&view=STANDARD', '@type': 'application/json'}], 'entry': [{'@_fa': 'true', 'load-date': '2020-09-25T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0141933120304294'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0141933120304294?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.micpro.2020.103270', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0141933120304294', 'dc:title': 'Hardware Root-of-Trust-based integrity for shared library function pointers in embedded systems', 'dc:creator': 'Patrick H. Coppock', 'prism:publicationName': 'Microprocessors and Microsystems', 'prism:volume': '79', 'prism:coverDate': '2020-11-30', 'prism:startingPage': '103270', 'prism:doi': '10.1016/j.micpro.2020.103270', 'openaccess': False, 'pii': 'S0141933120304294', 'authors': {'author': [{'$': 'Patrick H. Coppock'}, {'$': 'Momen K. Yacoub'}, {'$': 'Vincent J. Mooney'}]}}, {'@_fa': 'true', 'load-date': '2017-09-30T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0169023X17304457'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0169023X17304457?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.datak.2017.09.004', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0169023X17304457', 'dc:title': 'ZNS - Efficient query processing with ZurichNoSQL', 'dc:creator': 'Kurt Stockinger', 'prism:publicationName': 'Data & Knowledge Engineering', 'prism:volume': '112', 'prism:coverDate': '2017-11-30', 'prism:startingPage': '38', 'prism:endingPage': '54', 'prism:doi': '10.1016/j.datak.2017.09.004', 'openaccess': False, 'pii': 'S0169023X17304457', 'authors': {'author': [{'$': 'Kurt Stockinger'}, {'$': 'Richard Bödi'}, {'$': 'Thomas Weinmann'}]}}, {'@_fa': 'true', 'load-date': '2016-09-27T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0828282X16306638'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0828282X16306638?dgcid=api_sd_search-api-endpoint'}], 'dc:identifier': 'DOI:10.1016/j.cjca.2016.07.460', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0828282X16306638', 'dc:title': "THE IMPACT OF SOCIAL MEDIA ON CARDIOVASCULAR MEDICINE: INSIGHTS INTO TWITTER'S SPHERE OF INFLUENCE", 'dc:creator': 'P. Gouda', 'prism:publicationName': 'Canadian Journal of Cardiology', 'prism:volume': '32', 'prism:coverDate': '2016-10-31', 'prism:startingPage': 's281', 'prism:endingPage': 's282', 'prism:doi': '10.1016/j.cjca.2016.07.460', 'openaccess': False, 'pii': 'S0828282X16306638', 'authors': {'author': [{'$': 'P. Gouda'}, {'$': 'D. Das'}, {'$': 'J. Ezekowitz'}]}}, {'@_fa': 'true', 'load-date': '2016-12-21T00:00:00.000Z', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S1071916416312428'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https: ...

# %%
response
# Out:
# <Response [200]>
